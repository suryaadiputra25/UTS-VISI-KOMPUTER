# %%
from google.colab import drive
drive.mount('/content/drives')
# Out:
# Drive already mounted at /content/drives; to attempt to forcibly remount, call drive.mount("/content/drives", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drives/MyDrive/Colab Notebooks/sekolah.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1156x867>

# %%
img=cv2.imread('/content/drives/MyDrive/Colab Notebooks/sekolah.jpg', cv2.IMREAD_GRAYSCALE)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1156x867>

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
ret, img_binary = cv2.threshold(img, 50, 270, cv2.THRESH_BINARY)
plt.imshow(img_binary)
plt.show()
